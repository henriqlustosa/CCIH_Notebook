# %%
# importacao de bibliotecas
import pandas as pd
from unidecode import unidecode

# %load_ext sql

# %%
# Importacao da biblioteca sqlalchemy
from sqlalchemy import create_engine

# %%
## Conexão com a base de dados postgree

import pyodbc as podbc

cnxn = podbc.connect("Driver={SQL Server Native Client 11.0};Server=hspmins18;Database=Isolamento_Versao_2;uid=hspmApp;pwd=SoundG@rden=1")

# %%
## Acesso a base de dados

sql = "SELECT * FROM [Isolamento_Versao_2].[dbo].[LABORATORIO] WHERE     (Prontuario IS NULL) and parametroDataInicial = '2023-11-04 00:00:00.000' "
data_sql_server = pd.read_sql(sql,cnxn)

# %%
data_sql_server.head()
data_sql_server.shape
# Out:
# (52, 12)

# %%
# Primeiro, encontrar todos os nomes de pacientes e a data de nascimento para construção da query
# que fará o looping no banco de dadsos do SGH

sql = "SELECT NomePaciente, DataNascimento FROM [Isolamento_Versao_2].[dbo].[LABORATORIO] WHERE     (Prontuario IS NULL) and parametroDataInicial = '2023-11-04' group by NomePaciente, DataNascimento"
data_pacientes_laboratorio = pd.read_sql(sql,cnxn)

# %%
data_pacientes_laboratorio.shape
# Out:
# (37, 2)

# %%
import requests
import json
response_API = requests.get('http://intranethspm:5003//hspmsgh-api/assessor/paciente?nome=HENRIQUE%20LUSTOSA&?dataDeNascimento=1982-03-02')
print(response_API.status_code)
data = response_API.text

df = pd.read_json(data)
df.cd_prontuario.head(1)
# Out:
# 200
# 0    11209913
# Name: cd_prontuario, dtype: int64

# %%
data_sql_server.head(23)
# Out:
#    parametroDataInicial parametroDataFinal ParametroUsuarioLogado DataSistema  \
# 0            2023-04-11         2023-04-18                 133647  2023-04-14
# 1            2023-04-11         2023-04-18                 133647  2023-04-11
# 2            2023-04-11         2023-04-18                 133647  2023-04-13
# 3            2023-04-11         2023-04-18                 133647  2023-04-13
# 4            2023-04-11         2023-04-18                 133647  2023-04-11
# 5            2023-04-11         2023-04-18                 133647  2023-04-11
# 6            2023-04-11         2023-04-18                 133647  2023-04-11
# 7            2023-04-11         2023-04-18                 133647  2023-04-11
# 8            2023-04-11         2023-04-18                 133647  2023-04-13
# 9            2023-04-11         2023-04-18                 133647  2023-04-11
# 10           2023-04-11         2023-04-18                 133647  2023-04-11
# 11           2023-04-11         2023-04-18                 133647  2023-04-12
# 12           2023-04-11         2023-04-18                 133647  2023-04-12
# 13           2023-04-11         2023-04-18                 133647  2023-04-12
# 14           2023-04-11         2023-04-18                 133647  2023-04-13
# 15           2023-04-11         2023-04-18                 133647  2023-04-11
# 16           2023-04-11         2023-04-18                 133647  2023-04-11
# 17           2023-04-11         2023-04-18                 133647  2023-04-13
# 18           2023-04-11         2023-04-18                 133647  2023-04-13
# 19           2023-04-11         2023-04-18                 133647  2023-04-11
# 20           2023-04-11         2023-04-18                 133647  2023-04-16
# 21           2023-04-11         2023-04-18                 133647  2023-04-12
# 22           2023-04-11         2023-04-18                 133647  2023-04-11
#
#    Clinica                     NomeClinica NumeroPedido  \
# 0      11A                   11º AND_- ENF     10633833
# 1     5END     ENDOCRINOLOGIA_5º AND - AMB     10634935
# 2     5NEF         NEFROLOGIA_5º AND - AMB     10636371
# 3     6URO           UROLOGIA_6º AND - AMB     10636444
# 4      1PS   PRONTO SOCORRO ADULTO_1º AND      10632978
# 5     5VAS           VASCULAR_5º AND - AMB     10629170
# 6     5VAS           VASCULAR_5º AND - AMB     10629170
# 7       9B     9º AND_B - ENFERMARIA GERAL     10632427
# 8     TUCU                  TUCURUVI - AMB     10636353
# 9     6URO           UROLOGIA_6º AND - AMB     10634850
# 10    5NEF         NEFROLOGIA_5º AND - AMB     10634931
# 11     10A                   10º AND_- ENF     10631735
# 12     12A                  12º AND_ - ENF     10608592
# 13    TUCU                  TUCURUVI - AMB     10635518
# 14    5NEF         NEFROLOGIA_5º AND - AMB     10604400
# 15    6URO           UROLOGIA_6º AND - AMB     10634861
# 16      9B     9º AND_B - ENFERMARIA GERAL     10596669
# 17      9A     9º AND_A - ENFERMARIA GERAL     10632400
# 18      9B     9º AND_B - ENFERMARIA GERAL     10632774
# 19    4GNC        GINECOLOGIA_4º AND - AMB     10596100
# 20    1PSI  PRONTO SOCORRO INFANTI_1º AND      10628247
# 21    4HEM             HEMATOLOGIA_4º AND      10635481
# 22    6URO           UROLOGIA_6º AND - AMB     10634969
#
#                               NomePaciente DataNascimento  \
# 0                  AILTON MOREIRA DA SILVA     1965-03-21
# 1                   ALICE APARECIDA DASSOW     1956-06-10
# 2              ANA LUZIA FRISCIO DOMINGUES     1950-04-11
# 3                      ANA MOLINA CHIARATO     1936-08-04
# 4       ANGELA REGINA FERREIRA DE OLIVEIRA     1962-06-07
# 5                   ANTONIO GARCIA BENETON     1958-04-26
# 6                   ANTONIO GARCIA BENETON     1958-04-26
# 7                  BENJAMIM PEDRO DA SILVA     1954-04-15
# 8               CELMA MARIA DA SILVA PEDRO     1968-06-20
# 9                          CLAUDIO SECOLIN     1961-02-28
# 10             CRISTINA DELDUQUE PROMENZIO     1965-09-08
# 11                   DANIEL AMARAL ADEYEMI     1992-11-19
# 12        DORALICE ANGELA DE SOUZA BARBOSA     1939-09-27
# 13              EDNA MARIA SILVA DE AQUINO     1971-07-19
# 14               ELIENAE ALVES VASCONCELOS     1951-08-01
# 15             EUCLIDES GONÇALVES DA SILVA     1944-04-06
# 16  FABIANE APARECIDA FERREIRA DE OLIVEIRA     1979-04-03
# 17  FABIANE APARECIDA FERREIRA DE OLIVEIRA     1979-04-03
# 18  FABIANE APARECIDA FERREIRA DE OLIVEIRA     1979-04-03
# 19       FLAVIA REGINA DOMINGOS DOS SANTOS     1980-01-06
# 20                GIOVANNI AZZOLINI SANTIN     2021-12-18
# 21                   ISABEL MENDES GUERATO     1941-07-27
# 22                 JAILMA EDUARDA DA SILVA     1972-11-13
#
#                       Nome                                          Resultado  \
# 0               UROCULTURA                      Isolado [1]: Candida albicans
# 1               UROCULTURA                  Isolado [1]: Citrobacter freundii
# 2               UROCULTURA  Isolado [1]: Klebsiella pneumoniae ssp pneumoniae
# 3               UROCULTURA                 Isolado [1]: Enterococcus faecalis
# 4               UROCULTURA                     Isolado [1]: Proteus mirabilis
# 5            CULTURA GERAL                 Isolado [1]: Enterococcus faecalis
# 6            CULTURA GERAL  Enterococcus resistente a glicopeptideos (VRE)...
# 7            CULTURA GERAL                      Isolado [1]: Candida albicans
# 8               UROCULTURA                      Isolado [1]: Escherichia coli
# 9               UROCULTURA                      Isolado [1]: Escherichia coli
# 10              UROCULTURA                      Isolado [1]: Escherichia coli
# 11              UROCULTURA                Isolado [1]: Pseudomonas aeruginosa
# 12              UROCULTURA              Isolado [1]: Streptococcus agalactiae
# 13              UROCULTURA                      Isolado [1]: Escherichia coli
# 14              UROCULTURA                      Isolado [1]: Escherichia coli
# 15              UROCULTURA  Isolado [1]: Klebsiella pneumoniae ssp pneumoniae
# 16  HEMOCULTURA 1º AMOSTRA            Isolado [1]: Staphylococcus epidermidis
# 17              UROCULTURA                    Isolado [1]: Candida tropicalis
# 18              UROCULTURA                    Isolado [1]: Candida tropicalis
# 19              UROCULTURA                      Isolado [1]: Escherichia coli
# 20              UROCULTURA                     Isolado [1]: Proteus mirabilis
# 21              UROCULTURA                 Isolado [1]: Enterococcus faecalis
# 22              UROCULTURA                      Isolado [1]: Escherichia coli
#
#    Prontuario
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None

# %%
for index, row in data_pacientes_laboratorio.iterrows():
  
   
    response_API = requests.get('http://intranethspm:5003//hspmsgh-api/assessor/paciente?nome='+ row[0]+'&?dataDeNascimento='+ str(row[1]))
    print(response_API.status_code)
    data = response_API.text

    df = pd.read_json(data)

   

    
    if not df.empty:
        print(row[0])
        print('passei')
        print(str( df.cd_prontuario.head(1)[0]))
        sql2 = "UPDATE [Isolamento_Versao_2].[dbo].[Laboratorio] SET Prontuario = " + str(df.cd_prontuario.head(1)[0]) + " WHERE NomePaciente = '" + unidecode(row[0]) + "';"
        cnxn.execute(sql2)
# Out:
# 200
# AILTON MOREIRA DA SILVA
# passei
# 11259397
# 200
# ALICE APARECIDA DASSOW
# passei
# 11433539
# 200
# ANA LUZIA FRISCIO DOMINGUES
# passei
# 1556224
# 200
# ANA MOLINA CHIARATO
# passei
# 1761857
# 200
# ANGELA REGINA FERREIRA DE OLIVEIRA
# passei
# 4965364
# 200
# ANTONIO GARCIA BENETON
# passei
# 2715514
# 200
# BENJAMIM PEDRO DA SILVA
# passei
# 10307692
# 200
# CELMA MARIA DA SILVA PEDRO
# passei
# 10476315
# 200
# CLAUDIO SECOLIN
# passei
# 10879641
# 200
# 200
# DANIEL AMARAL ADEYEMI
# passei
# 11590635
# 200
# DORALICE ANGELA DE SOUZA BARBOSA
# passei
# 1866367
# 200
# EDNA MARIA SILVA DE AQUINO
# passei
# 12026019
# 200
# ELIENAE ALVES VASCONCELOS
# passei
# 3415791
# 200
# 200
# FABIANE APARECIDA FERREIRA DE OLIVEIRA
# passei
# 5017066
# 200
# FLAVIA REGINA DOMINGOS DOS SANTOS
# passei
# 11823044
# 200
# GIOVANNI AZZOLINI SANTIN
# passei
# 12222568
# 200
# ISABEL MENDES GUERATO
# passei
# 1394626
# 200
# JAILMA EDUARDA DA SILVA
# passei
# 11252640
# 200
# JOAO FRANCISCO DE SOUZA
# passei
# 2829539
# 200
# JOAO PEDRO DOS SANTOS ROCHA
# passei
# 12185815
# 200
# JOSE RAIMUNDO LANDIM
# passei
# 1413491
# 200
# LAURA DE ALMEIDA COUTINHO
# passei
# 12191391
# 200
# LAURA PINTO
# passei
# 65821
# 200
# LAURYN SHAKUR DORNELAS SANTOS SILVA
# passei
# 11505674
# 200
# MARIA ADILPHA SPINELLI
# passei
# 247312
# 200
# MARIA BENEDITA DE GOIS BARBOSA
# passei
# 861401
# 200
# MARIA BENEDITA DE SOUZA
# passei
# 111021
# 200
# MARIA INES RAMOS DA SILVA
# passei
# 5291117
# 200
# MARIA JOSE CORDEIRO
# passei
# 1561851
# 200
# 200
# SEBASTIAO JOSE SILVA
# passei
# 4510137
# 200
# VALENTYNA DE SOUZA RODRIGUES
# passei
# 11684107
# 200
# 200
# ZAQUEU PEREIRA CUNHA
# passei
# 2664837
# 200

# %%
cnxn.commit()
